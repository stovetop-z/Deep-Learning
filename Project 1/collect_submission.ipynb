# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cpsc8430/assignments/assignment1/'
FOLDERNAME = 'cpsc8430/assignments/project1/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %% [markdown]
# ## Collect Submission - Project 1
#
# Run this notebook once you have completed the main notebooks: `01_linear_feature.ipynb` and `02_softmax.ipynb`.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `project1_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `project1_inline_submission.pdf`.
#
# **IMPORTANT: Your submission must include:**
#
# **Note: Each notebook is worth 50% of the total project score:**
# - `01_linear_feature.ipynb`: 5 points (Linear Feature Classifier)
# - `02_softmax.ipynb`: 5 points (Softmax Implementation)
#
# 1. **ZIP file** (`project1_code_submission.zip`)
# 2. **Single PDF** (`project1_inline_submission.pdf`)
# 3. **Generated image file** (`all_weights_combined_(YOUR CUID).png`)
# 4. **Generated learnt image file** (`all_weights_combined_learned.png`)
#
# **Note: Each notebook is worth 50% of the total project score:**
# - `01_linear_feature.ipynb`: 5 points (Linear Feature Classifier)
# - `02_softmax.ipynb`: 5 points (Softmax Implementation)
#
# ***NOTE***: If your want to create the submission files locally, please carefully follow the instructions in README.md and run the .sh file:
# ```bash collectSubmission.sh```
#
#
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit project1_code_submission.zip, project1_inline_submission.pdf, all_weights_combined_(YOUR CUID).png, and all_weights_combined_learned.png to Gradescope. ###`
#
# Make sure to download all files locally to your computer, then submit to Gradescope. Congrats on successfully completing the project!

# %%
# %cd drive/My\ Drive
# %cd $FOLDERNAME

# Install required dependencies for PDF conversion
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2

# Check if the required notebooks exist
# !ls -la *.ipynb

# Run the submission script
# !bash collectSubmission.sh

# Verify the generated files
# !ls -la project1_* all_weights_combined*
